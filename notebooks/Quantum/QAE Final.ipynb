# %% [markdown]
# #Quantum Autoencoder implementation for IEEE-CIS, SECOM, and NSL-KDD Datasets

# %%
# !pip install pennylane numpy torch matplotlib pandas scikit-learn
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.40.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.4.2)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.7.0)
# Collecting tomlkit (from pennylane)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.40 (from pennylane)
#   Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.13.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (24.2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.40->pennylane)
#   Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.1.31)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Downloading PennyLane-0.40.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 34.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 5.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.2 MB/s eta 0:00:00
# Downloading autoray-0.7.1-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 44.7 MB/s eta 0:00:00
# Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.4 MB/s eta 0:00:00
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.0 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 12.5 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 95.3 MB/s eta 0:00:00
# Installing collected packages: appdirs, tomlkit, scipy-openblas32, rustworkx, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, autoray, nvidia-cusparse-cu12, nvidia-cudnn-cu12, diastatic-malt, nvidia-cusolver-cu12, pennylane-lightning, pennylane
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed appdirs-1.4.4 autoray-0.7.1 diastatic-malt-2.15.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pennylane-0.40.0 pennylane-lightning-0.40.0 rustworkx-0.16.0 scipy-openblas32-0.3.29.0.0 tomlkit-0.13.2

# %%
# Pennylane modules
import pennylane as qml
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import ConfusionMatrixDisplay, mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# from google.colab import drive
# drive.mount('/content/drive')

# %%
from qiskit_aer import Aer
from qiskit.quantum_info import SparsePauliOp
from qiskit_ibm_runtime import EstimatorV2 as Estimator, Sampler

# %%
from qiskit.circuit.library import QFT
from qiskit.providers.fake_provider import GenericBackendV2, generic_backend_v2

from qiskit import transpile, QuantumCircuit
from qiskit.circuit import Gate
from qiskit.converters import circuit_to_dag
from qiskit.transpiler import CouplingMap, StagedPassManager, PassManager, AnalysisPass, TransformationPass
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.transpiler.preset_passmanagers.common import generate_unroll_3q, generate_embed_passmanager
from qiskit.quantum_info import hellinger_fidelity
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.dagcircuit import DAGCircuit
from qiskit_ibm_runtime.fake_provider import FakeTorino

# transpiler passes
from qiskit.transpiler.passes.layout import csp_layout, dense_layout, sabre_layout, vf2_layout, trivial_layout
# Routing pa″sses
from qiskit.transpiler.passes.routing import basic_swap, lookahead_swap, sabre_swap
from qiskit.transpiler.passes.routing import star_prerouting
# Synthesis passes (passes for the translation stage)
from qiskit.circuit import SessionEquivalenceLibrary
from qiskit.circuit.equivalence_library import SessionEquivalenceLibrary
from qiskit.transpiler.passes.basis import basis_translator
from qiskit.transpiler.passes.synthesis import unitary_synthesis, high_level_synthesis
# Optimization passes
from qiskit.transpiler.passes.optimization import commutative_cancellation, consolidate_blocks, collect_2q_blocks, collect_1q_runs

# %% [markdown]
# ## Hyperparameters

# %%
step = 1e-2                 # Learning rate
batch_size = 16             # Number of samples for each training step
num_epochs = 20             # Number of training epochs
rng_seed = 42               # Seed for random number generator
n_qubits = 12                # Number of qubits
encoding_qubits = 2         # Number of qubits in the latent space
q_depth = 1                 # Depth of the quantum circuit (number of variational layers)
q_delta = 0.01              # Initial spread of random quantum weights

torch.manual_seed(rng_seed)
np.random.seed(rng_seed)

# %%
# Initialize quantum device
dev = qml.device('lightning.qubit', wires=n_qubits)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("mps") if torch.backends.mps.is_available() and torch.backends.mps.is_built() else device

# %% [markdown]
# ## Quantum Autoencoder Implementation

# %%
def angle_embedding(features, wires):
    """Embed classical features into quantum circuit using angle embedding"""
    qml.AngleEmbedding(features=features, wires=wires)

# %%
# def angle_embedding(features, wires, qc):
#     """Embed classical features into quantum circuit using angle embedding"""
    
#     for feature, qubit in zip(features, wires):
#         qc.ry(float(feature), qubit)

# %%
def layer(params, wires, i0=0, inc=1):
    """Single layer of rotations and entanglements"""
    # Rotations
    for i, wire in enumerate(wires):
        qml.Rot(*params[i0 + i * inc: i0 + (i + 1) * inc], wires=wire)

    # Entanglement
    for i in range(len(wires) - 1):
        qml.CNOT(wires=[wires[i], wires[i + 1]])

    # Connect last and first wire
    qml.CNOT(wires=[wires[-1], wires[0]])

# %%
# def layer(params, wires, qc, i0=0, inc=1):
#     """Single layer of rotations and entanglements"""

#     for i , wire in enumerate(wires):
#         phi, theta, omega = params[i0 + i * inc: i0 + (i + 1) * inc]
#         qc.u(float(theta), float(phi), float(omega), wire)
    
#     for i in range(len(wires)):
#         qc.cx(wires[i % len(wires)], wires[(i + 1) % len(wires)])

# %%
class QuantumAutoencoder(nn.Module):
    def __init__(self, n_features, n_qubits, encoding_qubits, q_depth):
        super(QuantumAutoencoder, self).__init__()

        self.n_features = n_features
        self.n_qubits = n_qubits
        self.encoding_qubits = encoding_qubits
        self.q_depth = q_depth

        # Define trainable parameters for encoder and decoder
        # Each qubit has 3 rotation parameters (Rot gate) for each layer
        encoder_params = 3 * n_qubits * q_depth
        decoder_params = 3 * n_qubits * q_depth

        # Initialize trainable parameters
        self.encoder_params = nn.Parameter(q_delta * torch.randn(encoder_params))
        self.decoder_params = nn.Parameter(q_delta * torch.randn(decoder_params))

        # Define the quantum device
        self.dev = qml.device('lightning.qubit', wires=n_qubits)

        # Define encoder and decoder circuits
        self.encoder_circuit = qml.QNode(self.encoder_function, self.dev, interface="torch")
        self.decoder_circuit = qml.QNode(self.decoder_function, self.dev, interface="torch")

    def encoder_function(self, x, params):
        """Quantum encoder circuit"""
        # Embed input data
        angle_embedding(x, wires=range(self.n_qubits))

        # Apply parametrized quantum circuit
        for d in range(self.q_depth):
            layer(params[d * 3 * self.n_qubits:(d + 1) * 3 * self.n_qubits],
                  wires=range(self.n_qubits),
                  i0=0,
                  inc=3)

        # Return expectation values for all qubits
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def decoder_function(self, latent, params):
        """Quantum decoder circuit"""
        # Reset qubits to |0>
        for i in range(self.n_qubits):
            if i < self.encoding_qubits:
                # Encode latent representation into fewer qubits
                # Map from [-1,1] to [0,π] for rotation angles
                angle = (latent[i] + 1) * np.pi / 2
                qml.RY(angle, wires=i)
            else:
                # Initialize remaining qubits to |0>
                qml.RY(0.0, wires=i)

        # Apply parametrized quantum circuit
        for d in range(self.q_depth):
            layer(params[d * 3 * self.n_qubits:(d + 1) * 3 * self.n_qubits],
                  wires=range(self.n_qubits),
                  i0=0,
                  inc=3)

        # Return expectation values for all qubits
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, x):
        """Forward pass through the quantum autoencoder"""
        batch_size = x.shape[0]
        results = torch.zeros((batch_size, self.n_features)).to(device)

        # Process each sample in the batch
        for i in range(batch_size):
            # Encode
            latent = self.encoder_circuit(x[i], self.encoder_params)

            # Take only the first encoding_qubits for the latent representation
            latent_reduced = latent[:self.encoding_qubits]

            # Decode
            decoded = self.decoder_circuit(latent_reduced, self.decoder_params)

            # Store results
            results[i] = torch.tensor(decoded[:self.n_features], device=device)

        return results

    def get_latent(self, x):
        """Get the latent space representation for a batch of inputs"""
        batch_size = x.shape[0]
        latent_space = torch.zeros((batch_size, self.encoding_qubits)).to(device)

        for i in range(batch_size):
            latent = self.encoder_circuit(x[i], self.encoder_params)
            latent_reduced = latent[:self.encoding_qubits]
            latent_space[i] = torch.tensor(latent_reduced, device=device)

        return latent_space

# %%
# class QuantumAutoencoder(nn.Module):
#     def __init__(self, n_features, n_qubits, encoding_qubits, q_depth, quantum_circuit, optimize, cm_type="line"):
#         super(QuantumAutoencoder, self).__init__()

#         self.n_features = n_features
#         self.n_qubits = n_qubits
#         self.encoding_qubits = encoding_qubits
#         self.q_depth = q_depth
#         self.quantum_circuit = quantum_circuit
#         self.optimize = optimize
#         self.cm_type = cm_type

#         # Define trainable parameters for encoder and decoder
#         # Each qubit has 3 rotation parameters (Rot gate) for each layer
#         encoder_params = 3 * n_qubits * q_depth
#         decoder_params = 3 * n_qubits * q_depth

#         # Initialize trainable parameters
#         self.encoder_params = nn.Parameter(q_delta * torch.randn(encoder_params))
#         self.decoder_params = nn.Parameter(q_delta * torch.randn(decoder_params))

#         # Define encoder and decoder circuits
#         self.encoder_circuit = self.encoder_function
#         self.decoder_circuit = self.decoder_function
    
#     def optimize_circuit(self, qc, type_local=None):
#         type_temp = self.cm_type
#         if type_local is not None:
#             type_temp = type_local

#         if type_temp == "line":
#             cm = CouplingMap.from_line(self.n_qubits)
#         elif type_temp == "ring":
#             cm = CouplingMap.from_ring(self.n_qubits)
#         elif type_temp == "full":
#             cm = CouplingMap.from_full(self.n_qubits)
#         elif type_temp == "grid":
#             cm = CouplingMap.from_grid(self.n_qubits)
#         elif type_temp == "hhex":
#             cm = CouplingMap.from_heavy_hex(self.n_qubits)
#         elif type_temp == "hsquare":
#             cm = CouplingMap.from_heavy_square(self.n_qubits)
#         elif type_temp == "hex":
#             cm = CouplingMap.from_hexagonal_lattice(self.n_qubits)
        
#         backend = GenericBackendV2(self.n_qubits, coupling_map=cm)
#         qc_routed = generate_preset_pass_manager(3, backend).run(qc)

#         return qc_routed
    
#     def return_function(self, qc):
#         backend_sim = Aer.get_backend('qasm_simulator')
#         estimator = Estimator(backend_sim)

#         observables = [SparsePauliOp("I"*_ + "Z" + "I"*(self.n_qubits - _ - 1)) for _ in range(self.n_qubits)]

#         theta = None
#         expectations = []

#         # job = estimator.run([qiskit_mid_circ], [observable])
#         for observable in observables:
#             if self.optimize:
#                 job = estimator.run([(self.optimize_circuit(qc), observable)])
#             else:
#                 job = estimator.run([(qc, observable)])

#             result = job.result()[0]
            
#             expectations.append(result.data.evs)
        
#         expectations = torch.tensor([float(x) for x in expectations])
#         # print("expectations in return_function:", expectations)

#         return expectations
    
#     def encoder_function(self, x, params):
#         """Quantum encoder circuit"""
#         # Embed input data
#         angle_embedding(x, range(self.n_qubits), self.quantum_circuit)

#         # Apply parametrized quantum circuit
#         for d in range(self.q_depth):
#             layer(params[d * 3 * self.n_qubits:(d + 1) * 3 * self.n_qubits],
#                   wires=range(self.n_qubits),
#                   qc=self.quantum_circuit,
#                   i0=0,
#                   inc=3)

#         # Return expectation values for all qubits
#         return self.return_function(self.quantum_circuit)
#         # return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]
    
    
#     def decoder_function(self, latent, params):
#         """Quantum decoder circuit"""
#         # Reset qubits to |0>
#         for i in range(self.n_qubits):
#             if i < self.encoding_qubits:
#                 # Encode latent representation into fewer qubits
#                 # Map from [-1,1] to [0,π] for rotation angles
#                 angle = (latent[i] + 1) * np.pi / 2
#                 self.quantum_circuit.ry(float(angle), i)
#             else:
#                 # Initialize remaining qubits to |0>
#                 self.quantum_circuit.ry(0.0, i)

#         # Apply parametrized quantum circuit
#         for d in range(self.q_depth):
#             layer(params[d * 3 * self.n_qubits:(d + 1) * 3 * self.n_qubits],
#                   wires=range(self.n_qubits),
#                   qc=self.quantum_circuit,
#                   i0=0,
#                   inc=3)

#         # Return expectation values for all qubits
#         return self.return_function(self.quantum_circuit)
#         # return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]
    
#     def forward(self, x):
#         """Forward pass through the quantum autoencoder"""
#         batch_size = x.shape[0]
#         results = torch.zeros((batch_size, self.n_features)).to(device)

#         # Process each sample in the batch
#         for i in range(batch_size):
#             # Encode
#             latent = self.encoder_circuit(x[i], self.encoder_params)

#             # Take only the first encoding_qubits for the latent representation
#             latent_reduced = latent[:self.encoding_qubits]

#             # Decode
#             decoded = self.decoder_circuit(latent_reduced, self.decoder_params)

#             # Store results
#             results[i] = torch.tensor(decoded[:self.n_features], device=device)

#         return results
    
#     def get_latent(self, x):
#         """Get the latent space representation for a batch of inputs"""
#         batch_size = x.shape[0]
#         latent_space = torch.zeros((batch_size, self.encoding_qubits)).to(device)

#         for i in range(batch_size):
#             latent = self.encoder_circuit(x[i], self.encoder_params)
#             latent_reduced = latent[:self.encoding_qubits]
#             latent_space[i] = torch.tensor(latent_reduced, device=device)

#         return latent_space
    
#     def get_circuit(self):
#         return self.quantum_circuit
    
#     def get_circuit_params(self):
#         return self.get_qc_chars(self.quantum_circuit)
    
#     def get_qc_chars(self, qc):
#         depth = qc.depth()
#         num_qubits = qc.num_qubits
#         ops = dict(qc.count_ops())
#         num_multi_qubit_ops = qc.num_nonlocal_gates()

#         return {"depth": depth, "num_qubits": num_qubits, "ops": ops, "num_multi_qubit_ops": num_multi_qubit_ops}

# %% [markdown]
# ## Data Loading & Preprocessing Functions

# %%
def normalize_data(X, scaler=None):
    """Normalize data to [0,1] or [-1,1] range"""
    if scaler is None:
        scaler = MinMaxScaler(feature_range=(-1, 1))
        return scaler.fit_transform(X), scaler
    else:
        return scaler.transform(X), scaler

# %%
def prepare_data_for_qae(X, batch_size=16):
    """Convert data to PyTorch dataset for QAE training"""
    # Convert to tensors
    X_tensor = torch.tensor(X, dtype=torch.float32).to(device)

    # Create dataset and data loader
    dataset = TensorDataset(X_tensor, X_tensor)  # Input = Target for autoencoder
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    return dataloader

# %%
import time

# %%
def train_qae(model, dataloader, val_dataloader, optimizer, epochs=50):
    """Train the quantum autoencoder"""
    # model.train()

    epoch_losses = []
    epoch_accuracies = []
    val_losses = []
    val_accuracies = []
    training_times = []

    for epoch in range(epochs):
        model.train()

        epoch_loss = 0.0
        total_correct = 0
        total_samples = 0

        start_time__epoch = time.time()
    
        for batch_features, _ in dataloader:
            batch_features = batch_features.to(device)

            # print("batch_features shape:", type(batch_features), batch_features.shape)

            # Forward pass
            start_time = time.time()
            outputs = model(batch_features)
            end_time = time.time()

            print("time taken for one model op:", end_time - start_time)
            # print("outputs:", outputs)

            # Calculate loss (MSE between input and reconstructed output)
            loss = nn.MSELoss()(outputs, batch_features)

            # Backward pass and optimize
            optimizer.zero_grad()
            loss.requires_grad = True
            loss.backward()
            optimizer.step()

            preds = (outputs > 0.5).float()
            total_correct += (preds == batch_features).sum().item()
            total_samples += batch_features.size(0)

            epoch_loss += loss.item()

        # Print progress
        avg_loss = epoch_loss / len(dataloader)
        epoch_losses.append(avg_loss)

        accuracy = total_correct / total_samples
        epoch_accuracies.append(accuracy)

        # Validation
        # model.eval()
        # val_loss, val_acc = 0, 0
        # with torch.no_grad():
        #     for x, y in val_dataloader:
        #         x, y = x.to(device), y.float().unsqueeze(1).to(device)
        #         outputs = model(x)
        #         loss = nn.MSELoss()(outputs, y)
        #         preds = (outputs > 0.5).float()
        #         val_acc += accuracy_score(y.cpu(), preds.cpu())
        #         val_loss += loss.item()
        
        # Store validation metrics
        # avg_val_loss = val_loss / len(val_dataloader)
        # avg_val_acc = val_acc / len(val_dataloader)
        # val_losses.append(avg_val_loss)
        # val_accuracies.append(avg_val_acc)

        end_time__epoch = time.time()
        training_times.append(end_time__epoch - start_time__epoch)

        # if (epoch + 1) % 5 == 0:
        #     print(f'Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.6f}')

        print(f"Epoch {epoch+1} | "
          f"Train Loss: {avg_loss:.4f} | "
          f"Train Acc: {accuracy:.4f} | "
        )
    
        # torch.save(model, F"/Users/soardr/VSCode Projects/Zenqor/Zenqor Drive/models/model training checkpoints QAE/model_IEEE__classical_opt___{epoch}.pt")

    # Plot training loss
    plt.figure(figsize=(10, 5))
    plt.plot(epoch_losses)
    plt.title('Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.show()

    return model, epoch_losses, epoch_accuracies, val_losses, val_accuracies

# %%
def train_qae__QNG(model, dataloader, epochs=50):
    optimizer = qml.QNGOptimizer(0.001)

    """Train the quantum autoencoder using QNG"""
    model.train()
    losses = []

    for epoch in range(epochs):
        epoch_loss = 0.0
        for batch_features, _ in dataloader:
            batch_features = batch_features.to(device)

            # print("batch_features shape:", type(batch_features), batch_features.shape)

            # Forward pass
            start_time = time.time()
            outputs = model(batch_features)
            end_time = time.time()

            print("time taken for one model op:", end_time - start_time)
            # print("outputs:", outputs)

            # Calculate loss (MSE between input and reconstructed output)
            loss = nn.MSELoss()(outputs, batch_features)

            # Backward pass and optimize
            optimizer.zero_grad()
            loss.requires_grad = True
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

        # Print progress
        avg_loss = epoch_loss / len(dataloader)
        losses.append(avg_loss)
        if (epoch + 1) % 5 == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.6f}')

    # Plot training loss
    plt.figure(figsize=(10, 5))
    plt.plot(losses)
    plt.title('Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.show()

    return model, losses

# %%
def evaluate_qae(model, X_tensor):
    """Evaluate the quantum autoencoder"""
    model.eval()
    with torch.no_grad():
        # Get reconstructed output
        reconstructed = model(X_tensor)

        # Calculate reconstruction error
        mse = nn.MSELoss()(reconstructed, X_tensor)

        # Get latent space representation
        latent = model.get_latent(X_tensor)

    return reconstructed, latent, mse.item()

# %%
def plot_latent_space(latent, labels=None):
    """Plot the latent space representation"""
    if latent.shape[1] >= 2:
        plt.figure(figsize=(10, 8))
        if labels is not None:
            unique_labels = np.unique(labels)
            for label in unique_labels:
                idx = labels == label
                plt.scatter(latent[idx, 0], latent[idx, 1], label=str(label))
            plt.legend()
        else:
            plt.scatter(latent[:, 0], latent[:, 1])
        plt.title('Latent Space Representation')
        plt.xlabel('Latent Dimension 1')
        plt.ylabel('Latent Dimension 2')
        plt.grid(True)
        plt.show()
    else:
        print("Latent space dimension is less than 2, cannot create 2D plot")

# %% [markdown]
# ## 1. IEEE-CIS Fraud Detection Dataset

# %%
# Load IEEE-CIS Fraud Detection Dataset
train_data_IEEE = pd.read_csv("/Users/soardr/VSCode Projects/Zenqor/data/IEEE-CIS/train_data.csv")
print(f"IEEE-CIS dataset shape: {train_data_IEEE.shape}")
# Out:
# IEEE-CIS dataset shape: (472432, 51)

# %%
train_data_IEEE = train_data_IEEE.sample(frac=1).reset_index(drop=True)

# %%
# Select a subset for computational efficiency (same as in QSVM)
# train_data_IEEE = train_data_IEEE[:1000]
train_data_IEEE = train_data_IEEE[:10000]

# %%
# Compute correlation matrix for feature selection
corr_matrix = train_data_IEEE.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, cmap='coolwarm', fmt=".2f", square=True)
plt.title("IEEE-CIS Correlation Matrix")
plt.show()

# %%
# Select the same features as in the QSVM implementation
features = ['TransactionAmt', 'card1', 'C1', 'C2']
X_IEEE = train_data_IEEE[features]
y_IEEE = train_data_IEEE['isFraud']

# %%
# Normalize features
X_IEEE_norm, ieee_scaler = normalize_data(X_IEEE)

# %%
# Split data
X_IEEE_train, X_IEEE_test, y_IEEE_train, y_IEEE_test = train_test_split(
    X_IEEE_norm, y_IEEE,
    test_size=0.2,
    random_state=42,
    stratify=y_IEEE,
    shuffle=True
)

# %%
# Prepare data loaders
ieee_train_loader = prepare_data_for_qae(X_IEEE_train, batch_size=batch_size)
ieee_test_loader = prepare_data_for_qae(X_IEEE_test, batch_size=batch_size)

# %%
quantum_circuit = QuantumCircuit(n_qubits)

# %%
device
# Out:
# device(type='mps')

# %%
# Create and train the IEEE-CIS QAE model
ieee_model = QuantumAutoencoder(
    n_features=len(features),
    n_qubits=n_qubits,
    encoding_qubits=encoding_qubits,
    q_depth=q_depth
    # quantum_circuit=quantum_circuit,
    # optimize=True
).to(device)

# %%
optimizer = optim.Adam(ieee_model.parameters(), lr=step)

# %% [markdown]
# ## Quantum Circuit params in defined model -- start

# %%
ieee_model.get_circuit_params()
# Out:
# {'depth': 1840,
#  'num_qubits': 12,
#  'ops': {'u': 1656, 'cx': 1656, 'ry': 368},
#  'num_multi_qubit_ops': 1656}

# %%
optimized_ieee_circuit_line = ieee_model.optimize_circuit(ieee_model.get_circuit(), type_local="line")
ieee_model.get_qc_chars(optimized_ieee_circuit_line)
# Out:
# {'depth': 7977,
#  'num_qubits': 12,
#  'ops': {'cx': 9267, 'rz': 6164, 'sx': 4143, 'x': 1},
#  'num_multi_qubit_ops': 9267}

# %%
optimized_ieee_circuit_ring = ieee_model.optimize_circuit(ieee_model.get_circuit(), type_local="ring")
ieee_model.get_qc_chars(optimized_ieee_circuit_ring)
# Out:
# {'depth': 2351,
#  'num_qubits': 12,
#  'ops': {'rz': 4971, 'sx': 3314, 'cx': 1656, 'x': 1},
#  'num_multi_qubit_ops': 1656}

# %%
optimized_ieee_circuit_full = ieee_model.optimize_circuit(ieee_model.get_circuit(), type_local="full")
ieee_model.get_qc_chars(optimized_ieee_circuit_full)
# Out:
# {'depth': 2351,
#  'num_qubits': 12,
#  'ops': {'rz': 4971, 'sx': 3314, 'cx': 1656, 'x': 1},
#  'num_multi_qubit_ops': 1656}

# %% [markdown]
# ## Quantum Circuit params in defined model -- end

# %%
print("Training IEEE-CIS Quantum Autoencoder...")
ieee_model, ieee_epoch_losses, ieee_epoch_accs, ieee_val_losses, ieee_val_accs = train_qae(
    model=ieee_model,
    dataloader=ieee_train_loader,
    val_dataloader=ieee_test_loader,
    optimizer=optimizer,
    epochs=num_epochs
)
# Out:
# Training IEEE-CIS Quantum Autoencoder...
# time taken for one model op: 1.0641980171203613
# time taken for one model op: 1.0494799613952637
# time taken for one model op: 0.9158608913421631
# time taken for one model op: 0.7879788875579834
# time taken for one model op: 0.7238888740539551
# time taken for one model op: 0.6878857612609863
# time taken for one model op: 0.5784718990325928
# time taken for one model op: 0.6045629978179932
# time taken for one model op: 0.906862735748291
# time taken for one model op: 0.6848809719085693
# time taken for one model op: 0.8680388927459717
# time taken for one model op: 0.6875777244567871
# time taken for one model op: 0.6157879829406738
# time taken for one model op: 0.5721161365509033
# time taken for one model op: 0.6467690467834473
# time taken for one model op: 0.6637611389160156
# time taken for one model op: 1.0119538307189941
# time taken for one model op: 0.5918691158294678
# time taken for one model op: 0.5783050060272217
# time taken for one model op: 0.5665369033813477
# time taken for one model op: 0.5943210124969482
# time taken for one model op: 0.5771341323852539
# time taken for one model op: 0.5512378215789795
# time taken for one model op: 0.5476150512695312
# time taken for one model op: 1.3624389171600342
# time taken for one model op: 0.5482480525970459
# time taken for one model op: 0.5644419193267822
# time taken for one model op: 0.5560598373413086
# time taken for one model op: 0.5623679161071777
# time taken for one model op: 0.5609581470489502
# time taken for one model op: 0.556678056716919
# time taken for one model op: 0.5548689365386963
# time taken for one model op: 0.5473980903625488
# time taken for one model op: 0.557218074798584
# time taken for one model op: 0.5677039623260498
# time taken for one model op: 0.6298091411590576
# time taken for one model op: 0.5804400444030762
# time taken for one model op: 0.5659687519073486
# time taken for one model op: 0.5679728984832764
# time taken for one model op: 0.5605289936065674
# time taken for one model op: 0.5492660999298096
# time taken for one model op: 0.5689859390258789
# time taken for one model op: 0.5583920478820801
# time taken for one model op: 0.613353967666626
# time taken for one model op: 0.5624921321868896
# time taken for one model op: 0.7864189147949219
# time taken for one model op: 0.9409842491149902
# time taken for one model op: 0.5979280471801758
# time taken for one model op: 0.5757219791412354
# time taken for one model op: 0.5735080242156982
# time taken for one model op: 0.5655028820037842
# time taken for one model op: 0.5697588920593262
# time taken for one model op: 0.5895888805389404
# time taken for one model op: 0.6658511161804199
# time taken for one model op: 0.5857388973236084
# time taken for one model op: 0.8332290649414062
# time taken for one model op: 0.607234001159668
# time taken for one model op: 0.5823831558227539
# time taken for one model op: 0.5656287670135498
# time taken for one model op: 0.5637118816375732
# time taken for one model op: 0.5584218502044678
# time taken for one model op: 0.5600659847259521
# time taken for one model op: 0.5560171604156494
# time taken for one model op: 0.5553901195526123
# time taken for one model op: 0.5705358982086182
# time taken for one model op: 0.8292911052703857
# time taken for one model op: 0.5355298519134521
# time taken for one model op: 0.5633049011230469
# time taken for one model op: 0.550137996673584
# time taken for one model op: 0.7456381320953369
# time taken for one model op: 0.618628978729248
# time taken for one model op: 0.5861649513244629
# time taken for one model op: 0.623615026473999
# time taken for one model op: 0.589400053024292
# time taken for one model op: 0.5517680644989014
# time taken for one model op: 0.5688540935516357
# time taken for one model op: 0.560168981552124
# time taken for one model op: 0.5473921298980713
# time taken for one model op: 0.5499758720397949
# time taken for one model op: 0.5406007766723633
# time taken for one model op: 0.5402748584747314
# time taken for one model op: 0.546821117401123
# time taken for one model op: 0.5424141883850098
# time taken for one model op: 0.5359728336334229
# time taken for one model op: 0.5442969799041748
# time taken for one model op: 0.536107063293457
# time taken for one model op: 0.6369597911834717
# time taken for one model op: 0.6826949119567871
# time taken for one model op: 1.1031250953674316
# time taken for one model op: 0.622870683670044
# time taken for one model op: 0.5595240592956543
# time taken for one model op: 0.5617399215698242
# time taken for one model op: 0.5669350624084473
# time taken for one model op: 0.5526959896087646
# time taken for one model op: 0.5447497367858887
# time taken for one model op: 0.5617361068725586
# time taken for one model op: 0.5841729640960693
# time taken for one model op: 0.6449410915374756
# time taken for one model op: 0.8344578742980957
# time taken for one model op: 0.8167171478271484
# time taken for one model op: 0.7308707237243652
# time taken for one model op: 0.5862650871276855
# time taken for one model op: 0.610893964767456
# time taken for one model op: 0.7494900226593018
# time taken for one model op: 0.8946418762207031
# time taken for one model op: 0.9619758129119873
# time taken for one model op: 0.7265141010284424
# time taken for one model op: 0.5781493186950684
# time taken for one model op: 0.5745599269866943
# time taken for one model op: 0.5654008388519287
# time taken for one model op: 0.5726668834686279
# time taken for one model op: 0.6113691329956055
# time taken for one model op: 0.5800199508666992
# time taken for one model op: 0.6244771480560303
# time taken for one model op: 0.5665626525878906
# time taken for one model op: 0.575610876083374
# time taken for one model op: 0.554063081741333
# time taken for one model op: 0.5658490657806396
# time taken for one model op: 0.557236909866333
# time taken for one model op: 0.553922176361084
# time taken for one model op: 0.5594890117645264
# time taken for one model op: 0.5492453575134277
# time taken for one model op: 0.5470538139343262
# time taken for one model op: 0.5587460994720459
# time taken for one model op: 0.7683761119842529
# time taken for one model op: 0.6558690071105957
# time taken for one model op: 0.7790520191192627
# time taken for one model op: 0.58443284034729
# time taken for one model op: 0.5753960609436035
# time taken for one model op: 0.5656766891479492
# time taken for one model op: 0.5596649646759033
# time taken for one model op: 0.750007152557373
# time taken for one model op: 0.574260950088501
# time taken for one model op: 0.576347827911377
# time taken for one model op: 0.6749169826507568
# time taken for one model op: 0.6277346611022949
# time taken for one model op: 0.585237979888916
# time taken for one model op: 0.5766949653625488
# time taken for one model op: 0.5566830635070801
# time taken for one model op: 0.5535869598388672
# time taken for one model op: 0.5456409454345703
# time taken for one model op: 0.5386049747467041
# time taken for one model op: 0.5431780815124512
# time taken for one model op: 0.533301830291748
# time taken for one model op: 0.5460937023162842
# time taken for one model op: 0.5300498008728027
# time taken for one model op: 0.8117020130157471
# time taken for one model op: 0.5442860126495361
# time taken for one model op: 0.5356199741363525
# time taken for one model op: 0.5409910678863525
# time taken for one model op: 0.5441100597381592
# time taken for one model op: 0.5323069095611572
# time taken for one model op: 0.5390541553497314
# time taken for one model op: 0.6311521530151367
# time taken for one model op: 0.992560863494873
# time taken for one model op: 1.9659011363983154
# time taken for one model op: 0.8796079158782959
# time taken for one model op: 0.720041036605835
# time taken for one model op: 0.6398041248321533
# time taken for one model op: 0.7519197463989258
# time taken for one model op: 0.8260416984558105
# time taken for one model op: 0.7080628871917725
# time taken for one model op: 0.5870819091796875
# time taken for one model op: 0.5661847591400146
# time taken for one model op: 0.5757091045379639
# time taken for one model op: 0.5660860538482666
# time taken for one model op: 0.8303179740905762
# time taken for one model op: 0.563396692276001
# time taken for one model op: 0.7709720134735107
# time taken for one model op: 0.64920973777771
# time taken for one model op: 0.8807029724121094
# time taken for one model op: 0.5842359066009521
# time taken for one model op: 0.529088020324707
# time taken for one model op: 0.5483028888702393
# time taken for one model op: 0.5528531074523926
# time taken for one model op: 0.5487430095672607
# time taken for one model op: 0.5596520900726318
# time taken for one model op: 0.7958929538726807
# time taken for one model op: 0.5782420635223389
# time taken for one model op: 0.6343259811401367
# time taken for one model op: 0.5669310092926025
# time taken for one model op: 0.5805630683898926
# time taken for one model op: 0.5568890571594238
# time taken for one model op: 0.5512030124664307
# time taken for one model op: 0.7116999626159668
# time taken for one model op: 0.6436619758605957
# time taken for one model op: 1.1848900318145752
# time taken for one model op: 0.60959792137146
# time taken for one model op: 0.8393957614898682
# time taken for one model op: 0.6633501052856445
# time taken for one model op: 0.5906922817230225
# time taken for one model op: 0.5616111755371094
# time taken for one model op: 0.5859682559967041
# time taken for one model op: 0.5655009746551514
# time taken for one model op: 0.5656280517578125
# time taken for one model op: 0.5715131759643555
# time taken for one model op: 0.8589367866516113
# time taken for one model op: 0.9367077350616455
# time taken for one model op: 0.6871380805969238
# time taken for one model op: 0.5898001194000244
# time taken for one model op: 0.5563399791717529
# time taken for one model op: 0.5623340606689453
# time taken for one model op: 0.5635738372802734
# time taken for one model op: 0.5565290451049805
# time taken for one model op: 0.5788929462432861
# time taken for one model op: 0.5535149574279785
# time taken for one model op: 0.5702259540557861
# time taken for one model op: 0.5692141056060791
# time taken for one model op: 0.5574331283569336
# time taken for one model op: 0.7239120006561279
# time taken for one model op: 0.6427469253540039
# time taken for one model op: 0.7320151329040527
# time taken for one model op: 0.6565637588500977
# time taken for one model op: 0.6145749092102051
# time taken for one model op: 0.5998449325561523
# time taken for one model op: 0.8520410060882568
# time taken for one model op: 0.5627901554107666
# time taken for one model op: 0.8699951171875
# time taken for one model op: 0.6388449668884277
# time taken for one model op: 0.765474796295166
# time taken for one model op: 0.6705563068389893
# time taken for one model op: 0.6133322715759277
# time taken for one model op: 0.6307220458984375
# time taken for one model op: 0.5719640254974365
# time taken for one model op: 0.5568561553955078
# time taken for one model op: 0.8593719005584717
# time taken for one model op: 0.7986278533935547
# time taken for one model op: 1.0015490055084229
# time taken for one model op: 0.8154568672180176
# time taken for one model op: 0.6258649826049805
# time taken for one model op: 0.7632508277893066
# time taken for one model op: 0.643563985824585
# time taken for one model op: 0.6276810169219971
# time taken for one model op: 0.6697690486907959
# time taken for one model op: 0.5650269985198975
# time taken for one model op: 0.6315839290618896
# time taken for one model op: 0.7479870319366455
# time taken for one model op: 1.086414098739624
# time taken for one model op: 0.7884228229522705
# time taken for one model op: 0.724517822265625
# time taken for one model op: 0.7570900917053223
# time taken for one model op: 0.5740690231323242
# time taken for one model op: 0.5553841590881348
# time taken for one model op: 0.6434879302978516
# time taken for one model op: 0.5579018592834473
# time taken for one model op: 0.5490338802337646
# time taken for one model op: 0.5731079578399658
# time taken for one model op: 0.6334431171417236
# time taken for one model op: 0.7275159358978271
# time taken for one model op: 0.5714759826660156
# time taken for one model op: 0.8329699039459229
# time taken for one model op: 0.6920309066772461
# time taken for one model op: 0.6684830188751221
# time taken for one model op: 0.6601781845092773
# time taken for one model op: 1.0301439762115479
# time taken for one model op: 0.7132210731506348
# time taken for one model op: 0.611853837966919
# time taken for one model op: 0.5881080627441406
# time taken for one model op: 0.5758030414581299
# time taken for one model op: 0.5866789817810059
# time taken for one model op: 0.5516960620880127
# time taken for one model op: 0.549799919128418
# time taken for one model op: 0.5417749881744385
# time taken for one model op: 0.5471780300140381
# time taken for one model op: 0.5734608173370361
# time taken for one model op: 0.7173240184783936
# time taken for one model op: 0.5651471614837646
# time taken for one model op: 0.8548500537872314
# time taken for one model op: 0.5420417785644531
# time taken for one model op: 0.6711950302124023
# time taken for one model op: 0.5673880577087402
# time taken for one model op: 0.9271519184112549
# time taken for one model op: 0.5524086952209473
# time taken for one model op: 0.5417318344116211
# time taken for one model op: 0.6069471836090088
# time taken for one model op: 0.5935909748077393
# time taken for one model op: 0.6087970733642578
# time taken for one model op: 0.5460269451141357
# time taken for one model op: 0.5315158367156982
# time taken for one model op: 0.5294389724731445
# time taken for one model op: 0.5802969932556152
# time taken for one model op: 0.701956033706665
# time taken for one model op: 0.5518620014190674
# time taken for one model op: 0.5858798027038574
# time taken for one model op: 0.9189798831939697
# time taken for one model op: 0.6912848949432373
# time taken for one model op: 1.1029791831970215
# time taken for one model op: 1.0568318367004395
# time taken for one model op: 0.9780490398406982
# time taken for one model op: 0.81606125831604
# time taken for one model op: 0.7159121036529541
# time taken for one model op: 0.5612070560455322
# time taken for one model op: 0.6815290451049805
# time taken for one model op: 0.5946359634399414
# time taken for one model op: 0.5628430843353271
# time taken for one model op: 0.6065537929534912
# time taken for one model op: 0.6329441070556641
# time taken for one model op: 0.5559499263763428
# time taken for one model op: 0.5605652332305908
# time taken for one model op: 0.5509202480316162
# time taken for one model op: 0.5807580947875977
# time taken for one model op: 0.7105350494384766
# time taken for one model op: 0.5654208660125732
# time taken for one model op: 0.6329269409179688
# time taken for one model op: 0.6800389289855957
# time taken for one model op: 0.5802528858184814
# time taken for one model op: 0.5522899627685547
# time taken for one model op: 0.6312739849090576
# time taken for one model op: 1.027890920639038
# time taken for one model op: 0.5636730194091797
# time taken for one model op: 0.5661270618438721
# time taken for one model op: 0.6692748069763184
# time taken for one model op: 0.6940019130706787
# time taken for one model op: 0.7113263607025146
# time taken for one model op: 0.7125251293182373
# time taken for one model op: 0.5661282539367676
# time taken for one model op: 0.5744447708129883
# time taken for one model op: 0.5749468803405762
# time taken for one model op: 0.5601179599761963
# time taken for one model op: 0.5611839294433594
# time taken for one model op: 0.5480670928955078
# time taken for one model op: 0.5624680519104004
# time taken for one model op: 0.5642831325531006
# time taken for one model op: 0.5492539405822754
# time taken for one model op: 0.5470678806304932
# time taken for one model op: 0.5699977874755859
# time taken for one model op: 0.562798023223877
# time taken for one model op: 0.538079023361206
# time taken for one model op: 0.5540900230407715
# time taken for one model op: 0.5834240913391113
# time taken for one model op: 0.6026291847229004
# time taken for one model op: 0.5928528308868408
# time taken for one model op: 0.583946943283081
# time taken for one model op: 0.5765581130981445
# time taken for one model op: 0.6689932346343994
# time taken for one model op: 0.6982772350311279
# time taken for one model op: 0.6975901126861572
# time taken for one model op: 0.7176260948181152
# time taken for one model op: 0.5659949779510498
# time taken for one model op: 0.6088438034057617
# time taken for one model op: 0.589104175567627
# time taken for one model op: 0.7325119972229004
# time taken for one model op: 0.6619620323181152
# time taken for one model op: 0.6109480857849121
# time taken for one model op: 0.6100080013275146
# time taken for one model op: 0.648493766784668
# time taken for one model op: 0.8071680068969727
# time taken for one model op: 0.71474289894104
# time taken for one model op: 1.024488925933838
# time taken for one model op: 0.7096269130706787
# time taken for one model op: 0.7476310729980469
# time taken for one model op: 0.6842830181121826
# time taken for one model op: 0.6824791431427002
# time taken for one model op: 0.6640739440917969
# time taken for one model op: 0.6814119815826416
# time taken for one model op: 0.724456787109375
# time taken for one model op: 0.6046628952026367
# time taken for one model op: 0.729788064956665
# time taken for one model op: 0.9961740970611572
# time taken for one model op: 0.8660058975219727
# time taken for one model op: 0.8492071628570557
# time taken for one model op: 0.9097998142242432
# time taken for one model op: 0.7674000263214111
# time taken for one model op: 0.7802021503448486
# time taken for one model op: 0.8636748790740967
# time taken for one model op: 0.7467648983001709
# time taken for one model op: 0.7317421436309814
# time taken for one model op: 0.6727962493896484
# time taken for one model op: 0.5990259647369385
# time taken for one model op: 0.6024971008300781
# time taken for one model op: 0.641315221786499
# time taken for one model op: 0.6035671234130859
# time taken for one model op: 0.5641050338745117
# time taken for one model op: 0.5587770938873291
# time taken for one model op: 0.6428918838500977
# time taken for one model op: 1.5904791355133057
# time taken for one model op: 0.826591968536377
# time taken for one model op: 0.6400389671325684
# time taken for one model op: 0.5595498085021973
# time taken for one model op: 1.0185842514038086
# time taken for one model op: 0.7642192840576172
# time taken for one model op: 0.6163730621337891
# time taken for one model op: 0.5828020572662354
# time taken for one model op: 0.6130478382110596
# time taken for one model op: 0.6553878784179688
# time taken for one model op: 0.7108638286590576
# time taken for one model op: 1.1780850887298584
# time taken for one model op: 0.9142038822174072
# time taken for one model op: 0.7299611568450928
# time taken for one model op: 0.9685640335083008
# time taken for one model op: 0.5795841217041016
# time taken for one model op: 0.6112470626831055
# time taken for one model op: 0.5792901515960693
# time taken for one model op: 0.5991458892822266
# time taken for one model op: 0.5784280300140381
# time taken for one model op: 0.761389970779419
# time taken for one model op: 0.7207398414611816
# time taken for one model op: 0.9784612655639648
# time taken for one model op: 0.7142078876495361
# time taken for one model op: 0.7179570198059082
# time taken for one model op: 0.6949808597564697
# time taken for one model op: 0.7192897796630859
# time taken for one model op: 0.6577472686767578
# time taken for one model op: 0.583625078201294
# time taken for one model op: 0.5701220035552979
# time taken for one model op: 0.5974757671356201
# time taken for one model op: 0.6684815883636475
# time taken for one model op: 0.7095890045166016
# time taken for one model op: 0.7089078426361084
# time taken for one model op: 0.7056319713592529
# time taken for one model op: 0.8779308795928955
# time taken for one model op: 0.8760058879852295
# time taken for one model op: 0.6058459281921387
# time taken for one model op: 0.574476957321167
# time taken for one model op: 0.5532338619232178
# time taken for one model op: 0.554840087890625
# time taken for one model op: 0.5543239116668701
# time taken for one model op: 0.5574140548706055
# time taken for one model op: 0.5595738887786865
# time taken for one model op: 0.5477449893951416
# time taken for one model op: 0.5596837997436523
# time taken for one model op: 0.5723021030426025
# time taken for one model op: 0.545781135559082
# time taken for one model op: 0.8090250492095947
# time taken for one model op: 0.5374681949615479
# time taken for one model op: 0.7046909332275391
# time taken for one model op: 0.722297191619873
# time taken for one model op: 0.5551018714904785
# time taken for one model op: 0.5491421222686768
# time taken for one model op: 0.5389618873596191
# time taken for one model op: 0.6003170013427734
# time taken for one model op: 0.5472118854522705
# time taken for one model op: 0.5335941314697266
# time taken for one model op: 0.5404939651489258
# time taken for one model op: 0.5785560607910156
# time taken for one model op: 0.5315029621124268
# time taken for one model op: 0.5264089107513428
# time taken for one model op: 0.5260670185089111
# time taken for one model op: 0.5223989486694336
# time taken for one model op: 0.5297031402587891
# time taken for one model op: 0.5363991260528564
# time taken for one model op: 0.7662069797515869
# time taken for one model op: 0.7644448280334473
# time taken for one model op: 0.7171189785003662
# time taken for one model op: 0.984713077545166
# time taken for one model op: 0.6906299591064453
# time taken for one model op: 0.5809259414672852
# time taken for one model op: 0.5706963539123535
# time taken for one model op: 0.5714943408966064
# time taken for one model op: 0.8033390045166016
# time taken for one model op: 0.5835268497467041
# time taken for one model op: 0.5751168727874756
# time taken for one model op: 0.5443739891052246
# time taken for one model op: 0.6574389934539795
# time taken for one model op: 0.6093220710754395
# time taken for one model op: 0.7549571990966797
# time taken for one model op: 0.6888890266418457
# time taken for one model op: 0.7296080589294434
# time taken for one model op: 0.7519540786743164
# time taken for one model op: 0.7335822582244873
# time taken for one model op: 0.6159000396728516
# time taken for one model op: 0.5913088321685791
# time taken for one model op: 0.580909013748169
# time taken for one model op: 0.8789207935333252
# time taken for one model op: 0.791234016418457
# time taken for one model op: 0.7955000400543213
# time taken for one model op: 0.725726842880249
# time taken for one model op: 0.7986741065979004
# time taken for one model op: 0.7689239978790283
# time taken for one model op: 0.6954119205474854
# time taken for one model op: 1.3033618927001953
# time taken for one model op: 1.635066032409668
# time taken for one model op: 1.1120758056640625
# time taken for one model op: 0.9053499698638916
# time taken for one model op: 1.0256907939910889
# time taken for one model op: 0.8445141315460205
# time taken for one model op: 0.7525770664215088
# time taken for one model op: 0.6716289520263672
# time taken for one model op: 0.7391879558563232
# time taken for one model op: 1.3977210521697998
# time taken for one model op: 0.8701510429382324
# time taken for one model op: 0.7364869117736816
# time taken for one model op: 0.6791739463806152
# time taken for one model op: 0.5732021331787109
# time taken for one model op: 0.7037522792816162
# time taken for one model op: 0.6094467639923096
# time taken for one model op: 0.6270520687103271
# time taken for one model op: 0.5871341228485107
# time taken for one model op: 0.5668509006500244
# time taken for one model op: 0.5564348697662354
# time taken for one model op: 0.5567398071289062
# time taken for one model op: 0.7181081771850586
# time taken for one model op: 0.6962881088256836
# time taken for one model op: 0.5753998756408691
# time taken for one model op: 0.6093780994415283
# time taken for one model op: 0.6558699607849121
# time taken for one model op: 0.5744221210479736
# time taken for one model op: 0.5700318813323975
# time taken for one model op: 0.5693938732147217
# time taken for one model op: 0.5771100521087646
# Epoch 1 | Train Loss: 0.9107 | Train Acc: 0.0000 |
# time taken for one model op: 0.5690078735351562
# time taken for one model op: 0.5504019260406494
# time taken for one model op: 0.5722339153289795
# time taken for one model op: 0.8793308734893799
# time taken for one model op: 0.5634019374847412
# time taken for one model op: 0.5671539306640625
# time taken for one model op: 0.5577878952026367
# time taken for one model op: 0.592689037322998
# time taken for one model op: 0.7318408489227295
# time taken for one model op: 0.7488870620727539
# time taken for one model op: 0.6610119342803955
# time taken for one model op: 0.5676732063293457
# time taken for one model op: 0.5668308734893799
# time taken for one model op: 0.6572601795196533
# time taken for one model op: 0.571850061416626
# time taken for one model op: 0.5586910247802734
# time taken for one model op: 0.5663189888000488
# time taken for one model op: 0.5617260932922363
# time taken for one model op: 0.6316709518432617
# time taken for one model op: 0.6614470481872559
# time taken for one model op: 0.7730302810668945
# time taken for one model op: 0.7204790115356445
# time taken for one model op: 0.6908817291259766
# time taken for one model op: 0.9149892330169678
# time taken for one model op: 0.6936111450195312
# time taken for one model op: 0.6911900043487549
# time taken for one model op: 0.7082219123840332
# time taken for one model op: 0.6954398155212402
# time taken for one model op: 0.7316060066223145
# time taken for one model op: 0.6248419284820557
# time taken for one model op: 0.690882682800293
# time taken for one model op: 0.6346356868743896
# time taken for one model op: 0.5697758197784424
# time taken for one model op: 0.5538039207458496
# time taken for one model op: 0.597343921661377
# time taken for one model op: 0.5669910907745361
# time taken for one model op: 0.8705720901489258
# time taken for one model op: 0.5810470581054688
# time taken for one model op: 0.5562407970428467
# time taken for one model op: 0.5662400722503662
# time taken for one model op: 0.5710480213165283
# time taken for one model op: 0.5558559894561768
# time taken for one model op: 0.6298298835754395
# time taken for one model op: 0.5824248790740967
# time taken for one model op: 0.5591311454772949
# time taken for one model op: 0.5973057746887207
# time taken for one model op: 0.536057710647583
# time taken for one model op: 0.546612024307251
# time taken for one model op: 0.5372581481933594
# time taken for one model op: 0.5293159484863281
# time taken for one model op: 0.5291850566864014
# time taken for one model op: 0.9602839946746826
# time taken for one model op: 0.8455071449279785
# time taken for one model op: 0.5868301391601562
# time taken for one model op: 0.5864419937133789
# time taken for one model op: 0.5706608295440674
# time taken for one model op: 0.5769317150115967
# time taken for one model op: 0.569782018661499
# time taken for one model op: 0.5529992580413818
# time taken for one model op: 0.5697050094604492
# time taken for one model op: 0.6755580902099609
# time taken for one model op: 0.5941047668457031
# time taken for one model op: 0.6233820915222168
# time taken for one model op: 0.5745048522949219
# time taken for one model op: 0.5634329319000244
# time taken for one model op: 0.5433290004730225
# time taken for one model op: 0.5418758392333984
# time taken for one model op: 0.5897789001464844
# time taken for one model op: 0.6775169372558594
# time taken for one model op: 0.6274011135101318
# time taken for one model op: 0.569209098815918
# time taken for one model op: 0.5581347942352295
# time taken for one model op: 0.7748970985412598
# time taken for one model op: 1.163705825805664
# time taken for one model op: 0.7998828887939453
# time taken for one model op: 0.7071318626403809
# time taken for one model op: 0.6999099254608154
# time taken for one model op: 0.9358272552490234
# time taken for one model op: 0.6159930229187012
# time taken for one model op: 0.5765001773834229
# time taken for one model op: 0.5480639934539795
# time taken for one model op: 0.5771429538726807
# time taken for one model op: 0.5529000759124756
# time taken for one model op: 0.5934078693389893
# time taken for one model op: 0.5499141216278076
# time taken for one model op: 0.7512478828430176
# time taken for one model op: 0.5557777881622314
# time taken for one model op: 0.556617021560669
# time taken for one model op: 0.5474779605865479
# time taken for one model op: 0.5479199886322021
# time taken for one model op: 0.5442538261413574
# time taken for one model op: 0.5514671802520752
# time taken for one model op: 0.5420973300933838
# time taken for one model op: 0.569047212600708
# time taken for one model op: 0.534019947052002
# time taken for one model op: 0.5424261093139648
# time taken for one model op: 0.5819752216339111
# time taken for one model op: 0.52736496925354
# time taken for one model op: 0.5657269954681396
# time taken for one model op: 0.5664081573486328
# time taken for one model op: 0.5523569583892822
# time taken for one model op: 0.5403821468353271
# time taken for one model op: 0.5473160743713379
# time taken for one model op: 0.5486721992492676
# time taken for one model op: 0.531102180480957
# time taken for one model op: 0.5453722476959229
# time taken for one model op: 0.5353541374206543
# time taken for one model op: 0.5324771404266357
# time taken for one model op: 0.5509059429168701
# time taken for one model op: 0.8268442153930664
# time taken for one model op: 0.6694431304931641
# time taken for one model op: 0.6818392276763916
# time taken for one model op: 0.6779508590698242
# time taken for one model op: 0.6463449001312256
# time taken for one model op: 0.5694417953491211
# time taken for one model op: 0.5313720703125
# time taken for one model op: 0.5486438274383545
# time taken for one model op: 0.9014818668365479
# time taken for one model op: 0.5565340518951416
# time taken for one model op: 0.5658149719238281
# time taken for one model op: 0.5472180843353271
# time taken for one model op: 0.5671370029449463
# time taken for one model op: 0.5623407363891602
# time taken for one model op: 0.569788932800293
# time taken for one model op: 0.558326005935669
# time taken for one model op: 0.5671689510345459
# time taken for one model op: 0.5299460887908936
# time taken for one model op: 0.5348067283630371
# time taken for one model op: 0.647104024887085
# time taken for one model op: 0.5820338726043701
# time taken for one model op: 0.6089119911193848
# time taken for one model op: 0.6045742034912109
# time taken for one model op: 0.5244960784912109
# time taken for one model op: 0.76092529296875
# time taken for one model op: 0.6985483169555664
# time taken for one model op: 0.6668691635131836
# time taken for one model op: 0.5786187648773193
# time taken for one model op: 0.5454342365264893
# time taken for one model op: 0.5314669609069824
# time taken for one model op: 0.5519769191741943
# time taken for one model op: 0.5317099094390869
# time taken for one model op: 0.5264801979064941
# time taken for one model op: 0.5315327644348145
# time taken for one model op: 0.547039270401001
# time taken for one model op: 0.5503437519073486
# time taken for one model op: 0.5363218784332275
# time taken for one model op: 0.5235302448272705
# time taken for one model op: 0.5482029914855957
# time taken for one model op: 0.5302503108978271
# time taken for one model op: 0.5359938144683838
# time taken for one model op: 0.9454536437988281
# time taken for one model op: 0.5667812824249268
# time taken for one model op: 0.5269088745117188
# time taken for one model op: 0.5264198780059814
# time taken for one model op: 0.5474753379821777
# time taken for one model op: 0.5851879119873047
# time taken for one model op: 0.5421512126922607
# time taken for one model op: 0.5313000679016113
# time taken for one model op: 0.793694019317627
# time taken for one model op: 0.5683059692382812
# time taken for one model op: 0.5344901084899902
# time taken for one model op: 0.5334699153900146
# time taken for one model op: 0.5421671867370605
# time taken for one model op: 0.5493800640106201
# time taken for one model op: 0.5282149314880371
# time taken for one model op: 0.5419571399688721
# time taken for one model op: 0.5346040725708008
# time taken for one model op: 0.5343339443206787
# time taken for one model op: 0.5339398384094238
# time taken for one model op: 0.5250449180603027
# time taken for one model op: 0.5323469638824463
# time taken for one model op: 0.5326452255249023
# time taken for one model op: 0.5311191082000732
# time taken for one model op: 0.5433297157287598
# time taken for one model op: 0.5269730091094971
# time taken for one model op: 0.540046215057373
# time taken for one model op: 0.5484750270843506
# time taken for one model op: 0.5348310470581055
# time taken for one model op: 0.5450842380523682
# time taken for one model op: 0.5409181118011475
# time taken for one model op: 0.5406467914581299
# time taken for one model op: 0.5584118366241455
# time taken for one model op: 0.5339710712432861
# time taken for one model op: 0.5495390892028809
# time taken for one model op: 0.6147341728210449
# time taken for one model op: 0.5476763248443604
# time taken for one model op: 0.5523810386657715
# time taken for one model op: 0.5301368236541748
# time taken for one model op: 0.5336401462554932
# time taken for one model op: 0.8267550468444824
# time taken for one model op: 0.5966510772705078
# time taken for one model op: 0.8912341594696045
# time taken for one model op: 0.6677858829498291
# time taken for one model op: 0.5462846755981445
# time taken for one model op: 0.6267061233520508
# time taken for one model op: 1.1279728412628174
# time taken for one model op: 0.6892552375793457
# time taken for one model op: 0.6747770309448242
# time taken for one model op: 1.0163488388061523
# time taken for one model op: 0.5617940425872803
# time taken for one model op: 0.5474579334259033
# time taken for one model op: 0.5405702590942383
# time taken for one model op: 0.5727658271789551
# time taken for one model op: 0.5373249053955078
# time taken for one model op: 0.5499508380889893
# time taken for one model op: 0.5480542182922363
# time taken for one model op: 0.5554070472717285
# time taken for one model op: 0.7618167400360107
# time taken for one model op: 0.6582038402557373
# time taken for one model op: 0.7192580699920654
# time taken for one model op: 0.8219189643859863
# time taken for one model op: 0.7747199535369873
# time taken for one model op: 0.8358860015869141
# time taken for one model op: 0.6427090167999268
# time taken for one model op: 0.6941049098968506
# time taken for one model op: 0.6429309844970703
# time taken for one model op: 0.6337077617645264
# time taken for one model op: 0.6286163330078125
# time taken for one model op: 0.621366024017334
# time taken for one model op: 0.575610876083374
# time taken for one model op: 0.5320136547088623
# time taken for one model op: 0.5432090759277344
# time taken for one model op: 0.5297636985778809
# time taken for one model op: 0.5379741191864014
# time taken for one model op: 0.547492265701294
# time taken for one model op: 0.5455498695373535
# time taken for one model op: 0.818734884262085
# time taken for one model op: 0.6591248512268066
# time taken for one model op: 0.9026648998260498
# time taken for one model op: 0.7990140914916992
# time taken for one model op: 0.9822409152984619
# time taken for one model op: 0.715766191482544
# time taken for one model op: 0.7010729312896729
# time taken for one model op: 0.683870792388916
# time taken for one model op: 0.6474471092224121
# time taken for one model op: 0.6072971820831299
# time taken for one model op: 0.5569629669189453
# time taken for one model op: 0.5370409488677979
# time taken for one model op: 0.5365850925445557
# time taken for one model op: 1.1697380542755127
# time taken for one model op: 0.7581052780151367
# time taken for one model op: 0.7005481719970703
# time taken for one model op: 0.7187247276306152
# time taken for one model op: 0.6718981266021729
# time taken for one model op: 0.569929838180542
# time taken for one model op: 0.7225191593170166
# time taken for one model op: 0.5525438785552979
# time taken for one model op: 0.532310962677002
# time taken for one model op: 0.5361802577972412
# time taken for one model op: 0.5636301040649414
# time taken for one model op: 0.6897580623626709
# time taken for one model op: 0.6059796810150146
# time taken for one model op: 0.5580458641052246
# time taken for one model op: 0.532167911529541
# time taken for one model op: 0.5622570514678955
# time taken for one model op: 0.5316219329833984
# time taken for one model op: 0.8345479965209961
# time taken for one model op: 0.7233099937438965
# time taken for one model op: 0.6703982353210449
# time taken for one model op: 0.8687939643859863
# time taken for one model op: 0.714914083480835
# time taken for one model op: 0.9411361217498779
# time taken for one model op: 0.7539730072021484
# time taken for one model op: 0.7433700561523438
# time taken for one model op: 0.6986560821533203
# time taken for one model op: 0.7226920127868652
# time taken for one model op: 0.9563238620758057
# time taken for one model op: 0.8072497844696045
# time taken for one model op: 0.720513105392456
# time taken for one model op: 0.6813900470733643
# time taken for one model op: 0.6733670234680176
# time taken for one model op: 0.6802749633789062
# time taken for one model op: 0.684016227722168
# time taken for one model op: 1.009397029876709
# time taken for one model op: 0.6746649742126465
# time taken for one model op: 0.6739270687103271
# time taken for one model op: 0.6151599884033203
# time taken for one model op: 0.578028678894043
# time taken for one model op: 0.5384941101074219
# time taken for one model op: 0.5633852481842041
# time taken for one model op: 0.5616328716278076
# time taken for one model op: 0.5329220294952393
# time taken for one model op: 0.5517261028289795
# time taken for one model op: 0.5342681407928467
# time taken for one model op: 0.5392379760742188
# time taken for one model op: 0.5670168399810791
# time taken for one model op: 0.5332727432250977
# time taken for one model op: 0.551987886428833
# time taken for one model op: 1.1218979358673096
# time taken for one model op: 1.014559030532837
# time taken for one model op: 0.8785049915313721
# time taken for one model op: 0.6604971885681152
# time taken for one model op: 0.6624221801757812
# time taken for one model op: 0.683096170425415
# time taken for one model op: 0.7432689666748047
# time taken for one model op: 0.8616578578948975
# time taken for one model op: 0.5733768939971924
# time taken for one model op: 0.6222901344299316
# time taken for one model op: 0.6088488101959229
# time taken for one model op: 0.5976357460021973
# time taken for one model op: 0.6183419227600098
# time taken for one model op: 0.5649819374084473
# time taken for one model op: 0.5386397838592529
# time taken for one model op: 0.6161599159240723
# time taken for one model op: 0.7375631332397461
# time taken for one model op: 0.6791789531707764
# time taken for one model op: 0.6429119110107422
# time taken for one model op: 0.7416629791259766
# time taken for one model op: 0.8219151496887207
# time taken for one model op: 0.7086391448974609
# time taken for one model op: 0.6913330554962158
# time taken for one model op: 0.8415048122406006
# time taken for one model op: 0.9279942512512207
# time taken for one model op: 1.032071828842163
# time taken for one model op: 0.7133910655975342
# time taken for one model op: 0.674936056137085
# time taken for one model op: 0.6841261386871338
# time taken for one model op: 0.6765060424804688
# time taken for one model op: 0.6189010143280029
# time taken for one model op: 0.562352180480957
# time taken for one model op: 0.5612459182739258
# time taken for one model op: 0.5581197738647461
# time taken for one model op: 0.7649309635162354
# time taken for one model op: 0.56144118309021
# time taken for one model op: 0.5486299991607666
# time taken for one model op: 1.1023898124694824
# time taken for one model op: 0.8120989799499512
# time taken for one model op: 0.6690137386322021
# time taken for one model op: 0.5610308647155762
# time taken for one model op: 0.5818779468536377
# time taken for one model op: 0.5800449848175049
# time taken for one model op: 0.5582950115203857
# time taken for one model op: 0.554440975189209
# time taken for one model op: 0.788517951965332
# time taken for one model op: 0.5875451564788818
# time taken for one model op: 0.5931978225708008
# time taken for one model op: 0.5691511631011963
# time taken for one model op: 0.5642430782318115
# time taken for one model op: 0.5895662307739258
# time taken for one model op: 0.552711009979248
# time taken for one model op: 0.5570380687713623
# time taken for one model op: 0.5625689029693604
# time taken for one model op: 0.5903239250183105
# time taken for one model op: 0.5753138065338135
# time taken for one model op: 0.5618181228637695
# time taken for one model op: 0.5662379264831543
# time taken for one model op: 0.7537779808044434
# time taken for one model op: 0.5636312961578369
# time taken for one model op: 0.5579080581665039
# time taken for one model op: 0.5708599090576172
# time taken for one model op: 0.6125531196594238
# time taken for one model op: 0.5700600147247314
# time taken for one model op: 0.587425947189331
# time taken for one model op: 0.8407559394836426
# time taken for one model op: 0.5726101398468018
# time taken for one model op: 0.6779031753540039
# time taken for one model op: 0.7719957828521729
# time taken for one model op: 0.6127219200134277
# time taken for one model op: 0.6033580303192139
# time taken for one model op: 0.6399061679840088
# time taken for one model op: 0.5903589725494385
# time taken for one model op: 0.5629279613494873
# time taken for one model op: 0.6117877960205078
# time taken for one model op: 0.6756231784820557
# time taken for one model op: 0.5791709423065186
# time taken for one model op: 0.6091601848602295
# time taken for one model op: 0.5915071964263916
# time taken for one model op: 0.5646898746490479
# time taken for one model op: 0.6063230037689209
# time taken for one model op: 0.573462963104248
# time taken for one model op: 0.6010169982910156
# time taken for one model op: 0.5950429439544678
# time taken for one model op: 0.581928014755249
# time taken for one model op: 0.5571658611297607
# time taken for one model op: 0.6256670951843262
# time taken for one model op: 0.6078901290893555
# time taken for one model op: 0.5765559673309326
# time taken for one model op: 0.603081226348877
# time taken for one model op: 0.6190149784088135
# time taken for one model op: 0.733604907989502
# time taken for one model op: 0.5515139102935791
# time taken for one model op: 0.5487239360809326
# time taken for one model op: 0.5357251167297363
# time taken for one model op: 0.5605242252349854
# time taken for one model op: 0.8421399593353271
# time taken for one model op: 0.5630857944488525
# time taken for one model op: 0.8638341426849365
# time taken for one model op: 0.5818328857421875
# time taken for one model op: 0.7598550319671631
# time taken for one model op: 0.593015193939209
# time taken for one model op: 0.585860013961792
# time taken for one model op: 0.5653078556060791
# time taken for one model op: 0.5801510810852051
# time taken for one model op: 0.552269697189331
# time taken for one model op: 0.5476679801940918
# time taken for one model op: 0.5494236946105957
# time taken for one model op: 0.545443058013916
# time taken for one model op: 0.5652658939361572
# time taken for one model op: 0.5865259170532227
# time taken for one model op: 0.5504031181335449
# time taken for one model op: 0.5413162708282471
# time taken for one model op: 0.5712430477142334
# time taken for one model op: 0.5856282711029053
# time taken for one model op: 0.5701539516448975
# time taken for one model op: 0.5527007579803467
# time taken for one model op: 0.5429441928863525
# time taken for one model op: 0.5499441623687744
# time taken for one model op: 0.5619232654571533
# time taken for one model op: 0.5461277961730957
# time taken for one model op: 0.5330502986907959
# time taken for one model op: 0.5463197231292725
# time taken for one model op: 0.5306379795074463
# time taken for one model op: 0.5470590591430664
# time taken for one model op: 0.5501527786254883
# time taken for one model op: 0.5306940078735352
# time taken for one model op: 0.5479791164398193
# time taken for one model op: 0.5321929454803467
# time taken for one model op: 0.6143350601196289
# time taken for one model op: 0.6206121444702148
# time taken for one model op: 0.561427116394043
# time taken for one model op: 0.8270232677459717
# time taken for one model op: 0.5757777690887451
# time taken for one model op: 0.5664529800415039
# time taken for one model op: 0.5332920551300049
# time taken for one model op: 0.5964579582214355
# time taken for one model op: 0.5635731220245361
# time taken for one model op: 0.5364439487457275
# time taken for one model op: 0.8443608283996582
# time taken for one model op: 0.5367767810821533
# time taken for one model op: 0.528501033782959
# time taken for one model op: 0.5463559627532959
# time taken for one model op: 0.5285282135009766
# time taken for one model op: 0.5327820777893066
# time taken for one model op: 0.732464075088501
# time taken for one model op: 0.5602931976318359
# time taken for one model op: 0.5331881046295166
# time taken for one model op: 0.5949540138244629
# time taken for one model op: 0.5320069789886475
# time taken for one model op: 0.5569500923156738
# time taken for one model op: 0.5629768371582031
# time taken for one model op: 0.5478429794311523
# time taken for one model op: 0.5430741310119629
# time taken for one model op: 0.7741081714630127
# time taken for one model op: 0.5692579746246338
# time taken for one model op: 0.531196117401123
# time taken for one model op: 0.54433274269104
# time taken for one model op: 0.5359091758728027
# time taken for one model op: 0.5281238555908203
# time taken for one model op: 0.5488572120666504
# time taken for one model op: 0.5339109897613525
# time taken for one model op: 0.540802001953125
# time taken for one model op: 0.534837007522583
# time taken for one model op: 0.5394580364227295
# time taken for one model op: 0.5231890678405762
# time taken for one model op: 0.531764030456543
# time taken for one model op: 0.5298330783843994
# time taken for one model op: 0.5359170436859131
# time taken for one model op: 0.5269770622253418
# time taken for one model op: 0.5487232208251953
# time taken for one model op: 0.5297532081604004
# time taken for one model op: 0.5550370216369629
# time taken for one model op: 0.52475905418396
# time taken for one model op: 0.5323038101196289
# time taken for one model op: 0.530797004699707
# time taken for one model op: 0.5317587852478027
# time taken for one model op: 0.5625731945037842
# time taken for one model op: 0.5488409996032715
# time taken for one model op: 0.819692850112915
# time taken for one model op: 0.5263330936431885
# time taken for one model op: 0.5477190017700195
# time taken for one model op: 0.5527560710906982
# time taken for one model op: 0.5514740943908691
# time taken for one model op: 0.6745219230651855
# time taken for one model op: 0.633760929107666
# time taken for one model op: 0.6023926734924316
# time taken for one model op: 0.5565578937530518
# time taken for one model op: 0.5478079319000244
# time taken for one model op: 0.542917013168335
# time taken for one model op: 0.5468606948852539
# time taken for one model op: 0.5346951484680176
# time taken for one model op: 0.5283970832824707
# time taken for one model op: 0.5356078147888184
# time taken for one model op: 0.524601936340332
# time taken for one model op: 0.5327720642089844
# time taken for one model op: 0.5481829643249512
# time taken for one model op: 0.5139930248260498
# time taken for one model op: 0.5134589672088623
# time taken for one model op: 0.5200481414794922
# time taken for one model op: 0.5031232833862305
# time taken for one model op: 0.5013439655303955
# time taken for one model op: 0.5114598274230957
# time taken for one model op: 0.5060708522796631
# time taken for one model op: 0.4931907653808594
# time taken for one model op: 0.5123357772827148
# time taken for one model op: 0.520287036895752
# time taken for one model op: 0.506195068359375
# time taken for one model op: 0.4633917808532715
# time taken for one model op: 0.4547140598297119
# time taken for one model op: 0.4429290294647217
# time taken for one model op: 0.4655730724334717
# Epoch 2 | Train Loss: 0.9107 | Train Acc: 0.0000 |
# ...
# time taken for one model op: 0.6075141429901123
# time taken for one model op: 0.608314037322998
# time taken for one model op: 0.6287200450897217
# time taken for one model op: 0.6055831909179688
# time taken for one model op: 0.6109681129455566
# time taken for one model op: 0.6079950332641602
# time taken for one model op: 0.6083602905273438
# time taken for one model op: 0.6271281242370605
# time taken for one model op: 0.6113038063049316
# time taken for one model op: 0.6081242561340332
# time taken for one model op: 0.8870232105255127
# time taken for one model op: 0.6113052368164062
# time taken for one model op: 0.6312849521636963
# time taken for one model op: 0.6084587574005127
# time taken for one model op: 0.6105270385742188
# time taken for one model op: 0.6073050498962402
# time taken for one model op: 0.6097071170806885
# time taken for one model op: 0.6357488632202148
# time taken for one model op: 0.607891321182251
# time taken for one model op: 0.6074039936065674
# time taken for one model op: 0.6098589897155762
# time taken for one model op: 0.6090381145477295
# time taken for one model op: 0.6241350173950195
# time taken for one model op: 0.6061379909515381
# time taken for one model op: 0.6077749729156494
# time taken for one model op: 0.6077530384063721
# time taken for one model op: 0.6151077747344971
# time taken for one model op: 0.6231687068939209
# time taken for one model op: 0.6067440509796143
# time taken for one model op: 0.6066079139709473
# time taken for one model op: 0.6115150451660156
# time taken for one model op: 0.6055657863616943
# time taken for one model op: 0.6273031234741211
# time taken for one model op: 0.6098427772521973
# time taken for one model op: 0.6086630821228027
# time taken for one model op: 0.6420447826385498
# time taken for one model op: 0.6066629886627197
# time taken for one model op: 0.6270649433135986
# time taken for one model op: 0.608123779296875
# time taken for one model op: 0.6063671112060547
# time taken for one model op: 0.6053099632263184
# time taken for one model op: 0.6135129928588867
# time taken for one model op: 0.6270718574523926
# time taken for one model op: 0.6077508926391602
# time taken for one model op: 0.6203510761260986
# time taken for one model op: 0.6073358058929443
# time taken for one model op: 0.607680082321167
# time taken for one model op: 0.6243219375610352
# time taken for one model op: 0.6052007675170898
# time taken for one model op: 0.6083090305328369
# time taken for one model op: 0.9090380668640137
# time taken for one model op: 0.6168608665466309
# time taken for one model op: 0.6263918876647949
# time taken for one model op: 0.6150162220001221
# time taken for one model op: 0.6166279315948486
# time taken for one model op: 0.6062591075897217
# time taken for one model op: 0.6131269931793213
# time taken for one model op: 0.6245121955871582
# time taken for one model op: 0.6069052219390869
# time taken for one model op: 0.6064481735229492
# time taken for one model op: 0.6095068454742432
# time taken for one model op: 0.608396053314209
# time taken for one model op: 0.6254301071166992
# time taken for one model op: 0.6081643104553223
# time taken for one model op: 0.6134231090545654
# time taken for one model op: 0.6074268817901611
# time taken for one model op: 0.6059987545013428
# time taken for one model op: 0.6273810863494873
# time taken for one model op: 0.6181371212005615
# time taken for one model op: 0.6077287197113037
# time taken for one model op: 0.6066620349884033
# time taken for one model op: 0.6123960018157959
# time taken for one model op: 0.625870943069458
# time taken for one model op: 0.6061019897460938
# time taken for one model op: 0.6084239482879639
# time taken for one model op: 0.6072719097137451
# time taken for one model op: 0.6089918613433838
# time taken for one model op: 0.6291069984436035
# time taken for one model op: 0.6090261936187744
# time taken for one model op: 0.6060948371887207
# time taken for one model op: 0.6116819381713867
# time taken for one model op: 0.6067187786102295
# time taken for one model op: 0.626641035079956
# time taken for one model op: 0.6081898212432861
# time taken for one model op: 0.6095991134643555
# time taken for one model op: 0.6081418991088867
# time taken for one model op: 0.6088142395019531
# time taken for one model op: 0.6259078979492188
# time taken for one model op: 0.6071791648864746
# time taken for one model op: 0.6139161586761475
# time taken for one model op: 0.6117310523986816
# time taken for one model op: 0.8161129951477051
# time taken for one model op: 0.6284351348876953
# time taken for one model op: 0.6072258949279785
# time taken for one model op: 0.6074299812316895
# time taken for one model op: 0.6050529479980469
# time taken for one model op: 0.6068229675292969
# time taken for one model op: 0.6251351833343506
# time taken for one model op: 0.6059749126434326
# time taken for one model op: 0.6093881130218506
# time taken for one model op: 0.6075069904327393
# time taken for one model op: 0.6067981719970703
# time taken for one model op: 0.6275241374969482
# time taken for one model op: 0.6114811897277832
# time taken for one model op: 0.6072115898132324
# time taken for one model op: 0.6099710464477539
# time taken for one model op: 0.6092438697814941
# time taken for one model op: 0.6257309913635254
# time taken for one model op: 0.6134600639343262
# time taken for one model op: 0.6106572151184082
# time taken for one model op: 0.6082310676574707
# time taken for one model op: 0.6075439453125
# time taken for one model op: 0.6363811492919922
# time taken for one model op: 0.6083040237426758
# time taken for one model op: 0.6001431941986084
# time taken for one model op: 0.599858283996582
# time taken for one model op: 0.6092140674591064
# time taken for one model op: 0.6261329650878906
# time taken for one model op: 0.6072847843170166
# time taken for one model op: 0.6082911491394043
# time taken for one model op: 0.6607820987701416
# time taken for one model op: 0.6121931076049805
# time taken for one model op: 0.6263790130615234
# time taken for one model op: 0.6081459522247314
# time taken for one model op: 0.6064808368682861
# time taken for one model op: 0.6125121116638184
# time taken for one model op: 0.6696188449859619
# time taken for one model op: 0.6744587421417236
# time taken for one model op: 0.6150779724121094
# time taken for one model op: 0.608583927154541
# time taken for one model op: 0.611008882522583
# time taken for one model op: 0.9511148929595947
# time taken for one model op: 0.6299238204956055
# time taken for one model op: 0.6056959629058838
# time taken for one model op: 0.6095459461212158
# time taken for one model op: 0.6231880187988281
# time taken for one model op: 0.620823860168457
# time taken for one model op: 0.6560640335083008
# time taken for one model op: 0.6080248355865479
# time taken for one model op: 0.6367919445037842
# time taken for one model op: 0.608198881149292
# time taken for one model op: 0.6053743362426758
# time taken for one model op: 0.6368987560272217
# time taken for one model op: 0.6097609996795654
# time taken for one model op: 0.6124100685119629
# time taken for one model op: 0.6076972484588623
# time taken for one model op: 0.6137769222259521
# time taken for one model op: 0.6256928443908691
# time taken for one model op: 0.6082170009613037
# time taken for one model op: 0.6105899810791016
# time taken for one model op: 0.6137778759002686
# time taken for one model op: 0.6083760261535645
# time taken for one model op: 0.63210129737854
# time taken for one model op: 0.6079709529876709
# time taken for one model op: 0.6075320243835449
# time taken for one model op: 0.607414960861206
# time taken for one model op: 0.6099169254302979
# time taken for one model op: 0.6277472972869873
# time taken for one model op: 0.6101202964782715
# time taken for one model op: 0.6080272197723389
# time taken for one model op: 0.6056630611419678
# time taken for one model op: 0.6139430999755859
# time taken for one model op: 0.6274130344390869
# time taken for one model op: 0.6065201759338379
# time taken for one model op: 0.6096320152282715
# time taken for one model op: 0.6118531227111816
# time taken for one model op: 0.6064059734344482
# time taken for one model op: 0.6245841979980469
# time taken for one model op: 0.6072287559509277
# time taken for one model op: 0.6074283123016357
# time taken for one model op: 0.6079690456390381
# time taken for one model op: 0.6068849563598633
# time taken for one model op: 0.9414610862731934
# time taken for one model op: 0.6090548038482666
# time taken for one model op: 0.6083590984344482
# time taken for one model op: 0.6076960563659668
# time taken for one model op: 0.6057689189910889
# time taken for one model op: 0.6240739822387695
# time taken for one model op: 0.5963649749755859
# time taken for one model op: 0.6055521965026855
# time taken for one model op: 0.5811011791229248
# time taken for one model op: 0.597545862197876
# time taken for one model op: 0.620513916015625
# time taken for one model op: 0.598114013671875
# time taken for one model op: 0.6002187728881836
# time taken for one model op: 0.6011059284210205
# time taken for one model op: 0.5953991413116455
# time taken for one model op: 0.6271071434020996
# time taken for one model op: 0.6033661365509033
# time taken for one model op: 0.6018459796905518
# time taken for one model op: 0.5946249961853027
# time taken for one model op: 0.6022660732269287
# time taken for one model op: 0.6350116729736328
# time taken for one model op: 0.59928297996521
# time taken for one model op: 0.6108391284942627
# time taken for one model op: 0.621392011642456
# time taken for one model op: 0.6450622081756592
# time taken for one model op: 0.7034642696380615
# time taken for one model op: 0.6185369491577148
# time taken for one model op: 0.5988380908966064
# time taken for one model op: 0.6032650470733643
# time taken for one model op: 0.607598066329956
# time taken for one model op: 0.6268527507781982
# time taken for one model op: 0.6082663536071777
# time taken for one model op: 0.6067216396331787
# time taken for one model op: 0.6088871955871582
# time taken for one model op: 0.9204502105712891
# time taken for one model op: 0.6362061500549316
# time taken for one model op: 0.6189188957214355
# time taken for one model op: 0.6166739463806152
# time taken for one model op: 0.6073470115661621
# time taken for one model op: 0.6114001274108887
# time taken for one model op: 0.6278009414672852
# time taken for one model op: 0.6082091331481934
# time taken for one model op: 0.6079497337341309
# time taken for one model op: 0.6142861843109131
# time taken for one model op: 0.6090319156646729
# time taken for one model op: 0.6245548725128174
# time taken for one model op: 0.6062839031219482
# time taken for one model op: 0.6127989292144775
# time taken for one model op: 0.60782790184021
# time taken for one model op: 0.6063971519470215
# time taken for one model op: 0.6306989192962646
# time taken for one model op: 0.6075789928436279
# time taken for one model op: 0.609813928604126
# time taken for one model op: 0.6084651947021484
# time taken for one model op: 0.6097171306610107
# time taken for one model op: 0.6550729274749756
# time taken for one model op: 0.6098799705505371
# time taken for one model op: 0.613490104675293
# time taken for one model op: 0.6120650768280029
# time taken for one model op: 0.6071350574493408
# time taken for one model op: 0.638159990310669
# time taken for one model op: 0.6183490753173828
# time taken for one model op: 0.6074271202087402
# time taken for one model op: 0.6087601184844971
# time taken for one model op: 0.6252682209014893
# time taken for one model op: 0.6249899864196777
# time taken for one model op: 0.6071169376373291
# time taken for one model op: 0.6093339920043945
# time taken for one model op: 0.606400728225708
# time taken for one model op: 0.6082971096038818
# time taken for one model op: 0.6265301704406738
# time taken for one model op: 0.609997034072876
# time taken for one model op: 0.6080930233001709
# time taken for one model op: 0.6055121421813965
# time taken for one model op: 0.9161219596862793
# time taken for one model op: 0.6359868049621582
# time taken for one model op: 0.6079368591308594
# time taken for one model op: 0.6132209300994873
# time taken for one model op: 0.6140470504760742
# time taken for one model op: 0.5984477996826172
# time taken for one model op: 0.6506528854370117
# time taken for one model op: 0.6657850742340088
# time taken for one model op: 0.613764762878418
# time taken for one model op: 0.6082139015197754
# time taken for one model op: 0.611731767654419
# time taken for one model op: 0.6300601959228516
# time taken for one model op: 0.7996511459350586
# time taken for one model op: 0.6232750415802002
# time taken for one model op: 0.6305711269378662
# time taken for one model op: 0.6139392852783203
# time taken for one model op: 0.6500887870788574
# time taken for one model op: 0.6061029434204102
# time taken for one model op: 0.8089640140533447
# time taken for one model op: 0.6754450798034668
# time taken for one model op: 0.776965856552124
# time taken for one model op: 0.683366060256958
# time taken for one model op: 0.6452891826629639
# time taken for one model op: 0.6091198921203613
# time taken for one model op: 0.6075830459594727
# time taken for one model op: 0.6060290336608887
# time taken for one model op: 0.6378231048583984
# time taken for one model op: 0.6219251155853271
# time taken for one model op: 0.6080291271209717
# time taken for one model op: 0.6112089157104492
# time taken for one model op: 0.6072559356689453
# time taken for one model op: 0.627708911895752
# time taken for one model op: 0.605370044708252
# time taken for one model op: 0.6060340404510498
# time taken for one model op: 0.6081409454345703
# time taken for one model op: 0.60732102394104
# time taken for one model op: 0.6256308555603027
# time taken for one model op: 0.6054637432098389
# time taken for one model op: 0.6039588451385498
# time taken for one model op: 0.6062798500061035
# time taken for one model op: 0.8901519775390625
# time taken for one model op: 0.6284151077270508
# time taken for one model op: 0.6145100593566895
# time taken for one model op: 0.6082749366760254
# time taken for one model op: 0.6109468936920166
# time taken for one model op: 0.6066429615020752
# time taken for one model op: 0.626971960067749
# time taken for one model op: 0.6080279350280762
# time taken for one model op: 0.607388973236084
# time taken for one model op: 0.6093580722808838
# time taken for one model op: 0.6084091663360596
# time taken for one model op: 0.6277768611907959
# time taken for one model op: 0.6099989414215088
# time taken for one model op: 0.6121900081634521
# time taken for one model op: 0.6311230659484863
# time taken for one model op: 0.6102390289306641
# time taken for one model op: 0.6332719326019287
# time taken for one model op: 0.6117599010467529
# time taken for one model op: 0.6159422397613525
# time taken for one model op: 0.6142580509185791
# time taken for one model op: 0.6298542022705078
# time taken for one model op: 0.6365461349487305
# time taken for one model op: 0.6079058647155762
# time taken for one model op: 0.6175999641418457
# time taken for one model op: 0.6152191162109375
# time taken for one model op: 0.6139509677886963
# time taken for one model op: 0.6307089328765869
# time taken for one model op: 0.6991422176361084
# time taken for one model op: 0.6115949153900146
# time taken for one model op: 0.6136608123779297
# time taken for one model op: 0.6118650436401367
# time taken for one model op: 0.6248922348022461
# time taken for one model op: 0.6140108108520508
# time taken for one model op: 0.8974609375
# time taken for one model op: 0.6101372241973877
# time taken for one model op: 0.6514041423797607
# time taken for one model op: 0.651080846786499
# time taken for one model op: 0.6086599826812744
# time taken for one model op: 0.6132621765136719
# time taken for one model op: 0.6272115707397461
# time taken for one model op: 0.6162190437316895
# time taken for one model op: 0.6374781131744385
# time taken for one model op: 0.6204581260681152
# time taken for one model op: 0.6211330890655518
# time taken for one model op: 0.6064119338989258
# time taken for one model op: 0.6114799976348877
# time taken for one model op: 0.6252017021179199
# Epoch 20 | Train Loss: 0.9107 | Train Acc: 0.0000 |

# %%
# Evaluate QAE on test data
X_IEEE_test_tensor = torch.tensor(X_IEEE_test, dtype=torch.float32).to(device)
reconstructed_IEEE, latent_IEEE, mse_IEEE = evaluate_qae(ieee_model, X_IEEE_test_tensor)

print(f"IEEE-CIS Test MSE: {mse_IEEE:.6f}")
# Out:
# IEEE-CIS Test MSE: 0.909549

# %%
# Plot latent space (colored by fraud label)
latent_IEEE_np = latent_IEEE.cpu().numpy()
y_IEEE_test_np = y_IEEE_test.values
plot_latent_space(latent_IEEE_np, y_IEEE_test_np)

# %%
# Visualize reconstruction quality for a few samples
plt.figure(figsize=(12, 5))
n_samples = 5
for i in range(n_samples):
    plt.subplot(2, n_samples, i + 1)
    plt.bar(range(len(features)), X_IEEE_test_tensor[i].cpu().numpy())
    plt.title(f"Original {i+1}")

    plt.subplot(2, n_samples, i + 1 + n_samples)
    plt.bar(range(len(features)), reconstructed_IEEE[i].cpu().numpy())
    plt.title(f"Reconstructed {i+1}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. SECOM Manufacturing Dataset

# %%
# Load SECOM Dataset
secom = pd.read_csv("/content/drive/MyDrive/Zenqor/datasets/uci-secom/uci-secom.csv")
print(f"SECOM dataset shape: {secom.shape}")
# Out:
# SECOM dataset shape: (1567, 592)

# %%
# Preprocess dataset as in the QSVM implementation
secom_ = secom.iloc[:, 1:-1]
secom_norm = (secom_ - secom_.min()) / (secom_.max() - secom_.min())
secom_norm.drop('13', axis=1, inplace=True)

# %%
# Drop specific columns as in the original code
for idx in range(238, 245, 1):
    if str(idx) in secom_norm.columns:
        secom_norm.drop(str(idx), axis=1, inplace=True)

# %%
# Select same features as in QSVM implementation
secom_norm__199_210 = secom_norm[[str(i) for i in range(199, 211, 1)]]
labels = secom.iloc[:, -1]
secom_norm__199_210['Pass/Fail'] = labels
# Out:
# <ipython-input-59-b0ef29e85ad8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   secom_norm__199_210['Pass/Fail'] = labels

# %%
# Fill or drop missing values
secom_norm__199_210 = secom_norm__199_210.dropna()
print(f"SECOM dataset after preprocessing: {secom_norm__199_210.shape}")
# Out:
# SECOM dataset after preprocessing: (1536, 13)

# %%
# Extract features and labels
X_SECOM = secom_norm__199_210.drop('Pass/Fail', axis=1)
y_SECOM = secom_norm__199_210['Pass/Fail']

# %%
# Normalize data
X_SECOM_norm, secom_scaler = normalize_data(X_SECOM)

# %%
# Split into train and test sets
X_SECOM_train, X_SECOM_test, y_SECOM_train, y_SECOM_test = train_test_split(
    X_SECOM_norm, y_SECOM,
    test_size=0.2,
    random_state=42,
    stratify=y_SECOM,
    shuffle=True
)

# %%
# Prepare data loaders
secom_train_loader = prepare_data_for_qae(X_SECOM_train, batch_size=batch_size)
secom_test_loader = prepare_data_for_qae(X_SECOM_test, batch_size=batch_size)

# %%
# Create and train the SECOM QAE model
# Use a subset of samples to match QSVM approach (for computational efficiency)
secom_samples = min(200, len(X_SECOM_train))
X_SECOM_subset = X_SECOM_train[:secom_samples]
subset_loader = prepare_data_for_qae(X_SECOM_subset, batch_size=batch_size)

secom_model = QuantumAutoencoder(
    n_features=X_SECOM.shape[1],
    n_qubits=n_qubits,
    encoding_qubits=encoding_qubits,
    q_depth=q_depth
).to(device)

optimizer = optim.Adam(secom_model.parameters(), lr=step)

print("Training SECOM Quantum Autoencoder...")
secom_model, secom_losses = train_qae(
    model=secom_model,
    dataloader=subset_loader,
    optimizer=optimizer,
    epochs=num_epochs
)
# Out:
# Training SECOM Quantum Autoencoder...
# Epoch [5/50], Loss: 1.413535
# Epoch [10/50], Loss: 1.413850
# Epoch [15/50], Loss: 1.411477
# Epoch [20/50], Loss: 1.414194
# Epoch [25/50], Loss: 1.413392
# Epoch [30/50], Loss: 1.413350
# Epoch [35/50], Loss: 1.412953
# Epoch [40/50], Loss: 1.413729
# Epoch [45/50], Loss: 1.412398
# Epoch [50/50], Loss: 1.412290

# %%
# Evaluate QAE on test data (use first 50 samples to match QSVM)
X_SECOM_test_tensor = torch.tensor(X_SECOM_test[:50], dtype=torch.float32).to(device)
reconstructed_SECOM, latent_SECOM, mse_SECOM = evaluate_qae(secom_model, X_SECOM_test_tensor)

print(f"SECOM Test MSE: {mse_SECOM:.6f}")
# Out:
# SECOM Test MSE: 1.417910

# %%
# Plot latent space (colored by class)
latent_SECOM_np = latent_SECOM.cpu().numpy()
y_SECOM_test_np = y_SECOM_test.iloc[:50].values
plot_latent_space(latent_SECOM_np, y_SECOM_test_np)

# %% [markdown]
# ## 3. NSL-KDD Intrusion Detection Datase

# %%
# Load NSL-KDD Dataset
NSLKDD_train = pd.read_csv("/content/drive/MyDrive/Zenqor/datasets/v2/NSL-KDD/Train.csv")
print(f"NSL-KDD dataset shape: {NSLKDD_train.shape}")
# Out:
# NSL-KDD dataset shape: (125973, 31)

# %%
# Select the same features as in the QSVM implementation
features_NSLKDD = ['serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
                  'dst_host_serror_rate', 'dst_host_srv_serror_rate']

# %%
# Extract features and labels
X_NSLKDD = NSLKDD_train[features_NSLKDD][:100]  # Use first 100 samples as in QSVM
y_NSLKDD = NSLKDD_train['class'][:100]

# %%
# Normalize data
X_NSLKDD_norm, nslkdd_scaler = normalize_data(X_NSLKDD)# Split into train and test sets
X_NSLKDD_train, X_NSLKDD_test, y_NSLKDD_train, y_NSLKDD_test = train_test_split(
    X_NSLKDD_norm, y_NSLKDD,
    test_size=0.2,
    random_state=42,
    stratify=y_NSLKDD,
    shuffle=True
)

# %%
# Prepare data loaders
nslkdd_train_loader = prepare_data_for_qae(X_NSLKDD_train, batch_size=batch_size)
nslkdd_test_loader = prepare_data_for_qae(X_NSLKDD_test, batch_size=batch_size)

# %%
# Create and train the NSL-KDD QAE model
nslkdd_model = QuantumAutoencoder(
    n_features=len(features_NSLKDD),
    n_qubits=n_qubits,
    encoding_qubits=encoding_qubits,
    q_depth=q_depth
).to(device)

optimizer = optim.Adam(nslkdd_model.parameters(), lr=step)

print("Training NSL-KDD Quantum Autoencoder...")
nslkdd_model, nslkdd_losses = train_qae(
    model=nslkdd_model,
    dataloader=nslkdd_train_loader,
    optimizer=optimizer,
    epochs=num_epochs
)
# Out:
# Training NSL-KDD Quantum Autoencoder...
# Epoch [5/50], Loss: 1.327751
# Epoch [10/50], Loss: 1.327751
# Epoch [15/50], Loss: 1.327751
# Epoch [20/50], Loss: 1.327751
# Epoch [25/50], Loss: 1.327751
# Epoch [30/50], Loss: 1.327751
# Epoch [35/50], Loss: 1.327751
# Epoch [40/50], Loss: 1.327751
# Epoch [45/50], Loss: 1.327751
# Epoch [50/50], Loss: 1.327751

# %%
# Evaluate QAE on test data
X_NSLKDD_test_tensor = torch.tensor(X_NSLKDD_test, dtype=torch.float32).to(device)
reconstructed_NSLKDD, latent_NSLKDD, mse_NSLKDD = evaluate_qae(nslkdd_model, X_NSLKDD_test_tensor)

print(f"NSL-KDD Test MSE: {mse_NSLKDD:.6f}")
# Out:
# NSL-KDD Test MSE: 1.176693

# %%
# Plot latent space (colored by class)
latent_NSLKDD_np = latent_NSLKDD.cpu().numpy()
y_NSLKDD_test_np = y_NSLKDD_test.values
plot_latent_space(latent_NSLKDD_np, y_NSLKDD_test_np)

# %% [markdown]
# ## Comparison of Latent Representations and Classification

# %%
# Function to train a classifier on latent space
def train_classifier_on_latent(latent_train, y_train, latent_test, y_test):
    """Train a classical SVM on latent space representations"""
    from sklearn.svm import SVC

    # Create and train classifier
    clf = SVC(kernel='rbf', class_weight='balanced', random_state=42)
    clf.fit(latent_train, y_train)

    # Make predictions
    y_pred = clf.predict(latent_test)

    # Compute accuracy
    acc = accuracy_score(y_test, y_pred)

    return acc, clf

# %% [markdown]
# ## Generate latent representation for all datasets

# %%
# IEEE-CIS
X_IEEE_train_tensor = torch.tensor(X_IEEE_train, dtype=torch.float32).to(device)
latent_IEEE_train = ieee_model.get_latent(X_IEEE_train_tensor).cpu().numpy()

# %%
# SECOM
X_SECOM_train_tensor = torch.tensor(X_SECOM_train[:200], dtype=torch.float32).to(device)
latent_SECOM_train = secom_model.get_latent(X_SECOM_train_tensor).cpu().numpy()

# %%
# NSL-KDD
X_NSLKDD_train_tensor = torch.tensor(X_NSLKDD_train, dtype=torch.float32).to(device)
latent_NSLKDD_train = nslkdd_model.get_latent(X_NSLKDD_train_tensor).cpu().numpy()

# %% [markdown]
# ##Train classifiers on latent representations

# %%
# IEEE-CIS
ieee_acc, ieee_clf = train_classifier_on_latent(
    latent_IEEE_train, y_IEEE_train,
    latent_IEEE_np, y_IEEE_test_np
)
print(f"IEEE-CIS Classification Accuracy on Latent Space: {ieee_acc:.4f}")
# Out:
# IEEE-CIS Classification Accuracy on Latent Space: 0.8350

# %%
# SECOM
secom_acc, secom_clf = train_classifier_on_latent(
    latent_SECOM_train, y_SECOM_train.iloc[:200],
    latent_SECOM_np, y_SECOM_test_np
)
print(f"SECOM Classification Accuracy on Latent Space: {secom_acc:.4f}")
# Out:
# SECOM Classification Accuracy on Latent Space: 0.8200

# %%
# NSL-KDD
nslkdd_acc, nslkdd_clf = train_classifier_on_latent(
    latent_NSLKDD_train, y_NSLKDD_train,
    latent_NSLKDD_np, y_NSLKDD_test_np
)
print(f"NSL-KDD Classification Accuracy on Latent Space: {nslkdd_acc:.4f}")
# Out:
# NSL-KDD Classification Accuracy on Latent Space: 0.8000

# %% [markdown]
# ## Comparative Summary

# %% [markdown]
# ## Dataset Reconstruction Performance
#
# | Dataset   | Reconstruction MSE | Latent Dimensions | Classification Acc |
# |-----------|-------------------|-------------------|-------------------|
# | IEEE-CIS  | 1.414884    | 2 qubits | 0.8350    |
# | SECOM     | 1.417910   | 2 qubits | 0.8200   |
# | NSL-KDD   | 1.176693  | 2 qubits | 0.8000  |

# %% [markdown]
# # Conclusion

# %% [markdown]
# The Quantum Autoencoder (QAE) implementation shows how quantum circuits can be used for dimensionality reduction across three different datasets. Key observations:
#
# 1. **Reconstruction Quality**: QAE effectively learns a compact representation of the data with reasonable reconstruction error.
#
# 2. **Latent Space**: The 2-qubit latent space often contains meaningful structure that preserves class separation.
#
# 3. **Classification Performance**: Training classical classifiers on the quantum latent representations produces respectable accuracy, though generally not as high as direct QSVM classification.
#
# 4. **Dataset Characteristics**: Performance varies by dataset complexity and structure. IEEE-CIS and SECOM benefit more from the quantum encoding than NSL-KDD.
#
# 5. **Computational Challenges**: QAE is more computationally intensive than QSVM, especially for larger datasets, necessitating the use of data subsets.
#
# The results demonstrate that quantum autoencoders can effectively extract meaningful low-dimensional representations that preserve important information from the original data, though with different strengths compared to direct quantum classification methods like QSVM.
